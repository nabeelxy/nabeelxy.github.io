# %%
from covid19 import covid_data
jhu_data = covid_data.load_jhu_data()
len(jhu_data.values())
# Out:
# ERROR:root:Unknown country: Diamond Princess
# ERROR:root:Unknown country: MS Zaandam
# 189

# %%
country_ids = list(jhu_data.keys())
country_ids[0], country_ids[-1]
# Out:
# ('AF', 'ZW')

# %%
jhu_data['LK']
# Out:
# {'country_name': 'Sri Lanka',
#  'country_alpha_2': 'LK',
#  'country_alpha_3': 'LKA',
#  'population': 21803000,
#  'timeseries': [{'date': '2020-01-22 00:00:00',
#    'unixtime': 1579640400,
#    'cum_confirmed': 0,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-01-23 00:00:00',
#    'unixtime': 1579726800,
#    'cum_confirmed': 0,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-01-24 00:00:00',
#    'unixtime': 1579813200,
#    'cum_confirmed': 0,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-01-25 00:00:00',
#    'unixtime': 1579899600,
#    'cum_confirmed': 0,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-01-26 00:00:00',
#    'unixtime': 1579986000,
#    'cum_confirmed': 0,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-01-27 00:00:00',
#    'unixtime': 1580072400,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 1,
#    'new_confirmed': 1,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-01-28 00:00:00',
#    'unixtime': 1580158800,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 1,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-01-29 00:00:00',
#    'unixtime': 1580245200,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 1,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-01-30 00:00:00',
#    'unixtime': 1580331600,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 1,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-01-31 00:00:00',
#    'unixtime': 1580418000,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 1,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-01 00:00:00',
#    'unixtime': 1580504400,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 1,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-02 00:00:00',
#    'unixtime': 1580590800,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 1,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-03 00:00:00',
#    'unixtime': 1580677200,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 1,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-04 00:00:00',
#    'unixtime': 1580763600,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 1,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-05 00:00:00',
#    'unixtime': 1580850000,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 1,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-06 00:00:00',
#    'unixtime': 1580936400,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 1,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-07 00:00:00',
#    'unixtime': 1581022800,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 0,
#    'active': 1,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-08 00:00:00',
#    'unixtime': 1581109200,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 1,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-09 00:00:00',
#    'unixtime': 1581195600,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-10 00:00:00',
#    'unixtime': 1581282000,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-11 00:00:00',
#    'unixtime': 1581368400,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-12 00:00:00',
#    'unixtime': 1581454800,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-13 00:00:00',
#    'unixtime': 1581541200,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-14 00:00:00',
#    'unixtime': 1581627600,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-15 00:00:00',
#    'unixtime': 1581714000,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-16 00:00:00',
#    'unixtime': 1581800400,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-17 00:00:00',
#    'unixtime': 1581886800,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-18 00:00:00',
#    'unixtime': 1581973200,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-19 00:00:00',
#    'unixtime': 1582059600,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-20 00:00:00',
#    'unixtime': 1582146000,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-21 00:00:00',
#    'unixtime': 1582232400,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-22 00:00:00',
#    'unixtime': 1582318800,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-23 00:00:00',
#    'unixtime': 1582405200,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-24 00:00:00',
#    'unixtime': 1582491600,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-25 00:00:00',
#    'unixtime': 1582578000,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-26 00:00:00',
#    'unixtime': 1582664400,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-27 00:00:00',
#    'unixtime': 1582750800,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-28 00:00:00',
#    'unixtime': 1582837200,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-02-29 00:00:00',
#    'unixtime': 1582923600,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-01 00:00:00',
#    'unixtime': 1583010000,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-02 00:00:00',
#    'unixtime': 1583096400,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-03 00:00:00',
#    'unixtime': 1583182800,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-04 00:00:00',
#    'unixtime': 1583269200,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-05 00:00:00',
#    'unixtime': 1583355600,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-06 00:00:00',
#    'unixtime': 1583442000,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-07 00:00:00',
#    'unixtime': 1583528400,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-08 00:00:00',
#    'unixtime': 1583614800,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-09 00:00:00',
#    'unixtime': 1583701200,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-10 00:00:00',
#    'unixtime': 1583787600,
#    'cum_confirmed': 1,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 0,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-11 00:00:00',
#    'unixtime': 1583874000,
#    'cum_confirmed': 2,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 1,
#    'new_confirmed': 1,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-12 00:00:00',
#    'unixtime': 1583960400,
#    'cum_confirmed': 2,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 1,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-13 00:00:00',
#    'unixtime': 1584046800,
#    'cum_confirmed': 6,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 5,
#    'new_confirmed': 4,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-14 00:00:00',
#    'unixtime': 1584133200,
#    'cum_confirmed': 10,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 9,
#    'new_confirmed': 4,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-15 00:00:00',
#    'unixtime': 1584219600,
#    'cum_confirmed': 18,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 17,
#    'new_confirmed': 8,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-16 00:00:00',
#    'unixtime': 1584306000,
#    'cum_confirmed': 28,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 27,
#    'new_confirmed': 10,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-17 00:00:00',
#    'unixtime': 1584392400,
#    'cum_confirmed': 44,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 43,
#    'new_confirmed': 16,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-18 00:00:00',
#    'unixtime': 1584478800,
#    'cum_confirmed': 51,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 50,
#    'new_confirmed': 7,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-19 00:00:00',
#    'unixtime': 1584565200,
#    'cum_confirmed': 60,
#    'cum_deaths': 0,
#    'cum_recovered': 3,
#    'active': 57,
#    'new_confirmed': 9,
#    'new_deaths': 0,
#    'new_recovered': 2,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-20 00:00:00',
#    'unixtime': 1584651600,
#    'cum_confirmed': 73,
#    'cum_deaths': 0,
#    'cum_recovered': 3,
#    'active': 70,
#    'new_confirmed': 13,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-21 00:00:00',
#    'unixtime': 1584738000,
#    'cum_confirmed': 77,
#    'cum_deaths': 0,
#    'cum_recovered': 1,
#    'active': 76,
#    'new_confirmed': 4,
#    'new_deaths': 0,
#    'new_recovered': -2,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-22 00:00:00',
#    'unixtime': 1584824400,
#    'cum_confirmed': 82,
#    'cum_deaths': 0,
#    'cum_recovered': 3,
#    'active': 79,
#    'new_confirmed': 5,
#    'new_deaths': 0,
#    'new_recovered': 2,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-23 00:00:00',
#    'unixtime': 1584910800,
#    'cum_confirmed': 97,
#    'cum_deaths': 0,
#    'cum_recovered': 3,
#    'active': 94,
#    'new_confirmed': 15,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-24 00:00:00',
#    'unixtime': 1584997200,
#    'cum_confirmed': 102,
#    'cum_deaths': 0,
#    'cum_recovered': 2,
#    'active': 100,
#    'new_confirmed': 5,
#    'new_deaths': 0,
#    'new_recovered': -1,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-25 00:00:00',
#    'unixtime': 1585083600,
#    'cum_confirmed': 102,
#    'cum_deaths': 0,
#    'cum_recovered': 3,
#    'active': 99,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 1,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-26 00:00:00',
#    'unixtime': 1585170000,
#    'cum_confirmed': 106,
#    'cum_deaths': 0,
#    'cum_recovered': 7,
#    'active': 99,
#    'new_confirmed': 4,
#    'new_deaths': 0,
#    'new_recovered': 4,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-27 00:00:00',
#    'unixtime': 1585256400,
#    'cum_confirmed': 106,
#    'cum_deaths': 0,
#    'cum_recovered': 7,
#    'active': 99,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-28 00:00:00',
#    'unixtime': 1585342800,
#    'cum_confirmed': 113,
#    'cum_deaths': 1,
#    'cum_recovered': 9,
#    'active': 103,
#    'new_confirmed': 7,
#    'new_deaths': 1,
#    'new_recovered': 2,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-29 00:00:00',
#    'unixtime': 1585429200,
#    'cum_confirmed': 117,
#    'cum_deaths': 1,
#    'cum_recovered': 11,
#    'active': 105,
#    'new_confirmed': 4,
#    'new_deaths': 0,
#    'new_recovered': 2,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-30 00:00:00',
#    'unixtime': 1585515600,
#    'cum_confirmed': 122,
#    'cum_deaths': 2,
#    'cum_recovered': 15,
#    'active': 105,
#    'new_confirmed': 5,
#    'new_deaths': 1,
#    'new_recovered': 4,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-03-31 00:00:00',
#    'unixtime': 1585602000,
#    'cum_confirmed': 143,
#    'cum_deaths': 2,
#    'cum_recovered': 17,
#    'active': 124,
#    'new_confirmed': 21,
#    'new_deaths': 0,
#    'new_recovered': 2,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-01 00:00:00',
#    'unixtime': 1585688400,
#    'cum_confirmed': 146,
#    'cum_deaths': 3,
#    'cum_recovered': 21,
#    'active': 122,
#    'new_confirmed': 3,
#    'new_deaths': 1,
#    'new_recovered': 4,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-02 00:00:00',
#    'unixtime': 1585774800,
#    'cum_confirmed': 151,
#    'cum_deaths': 4,
#    'cum_recovered': 21,
#    'active': 126,
#    'new_confirmed': 5,
#    'new_deaths': 1,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-03 00:00:00',
#    'unixtime': 1585861200,
#    'cum_confirmed': 159,
#    'cum_deaths': 4,
#    'cum_recovered': 24,
#    'active': 131,
#    'new_confirmed': 8,
#    'new_deaths': 0,
#    'new_recovered': 3,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-04 00:00:00',
#    'unixtime': 1585947600,
#    'cum_confirmed': 166,
#    'cum_deaths': 5,
#    'cum_recovered': 27,
#    'active': 134,
#    'new_confirmed': 7,
#    'new_deaths': 1,
#    'new_recovered': 3,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-05 00:00:00',
#    'unixtime': 1586034000,
#    'cum_confirmed': 176,
#    'cum_deaths': 5,
#    'cum_recovered': 33,
#    'active': 138,
#    'new_confirmed': 10,
#    'new_deaths': 0,
#    'new_recovered': 6,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-06 00:00:00',
#    'unixtime': 1586120400,
#    'cum_confirmed': 178,
#    'cum_deaths': 5,
#    'cum_recovered': 38,
#    'active': 135,
#    'new_confirmed': 2,
#    'new_deaths': 0,
#    'new_recovered': 5,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-07 00:00:00',
#    'unixtime': 1586206800,
#    'cum_confirmed': 185,
#    'cum_deaths': 6,
#    'cum_recovered': 42,
#    'active': 137,
#    'new_confirmed': 7,
#    'new_deaths': 1,
#    'new_recovered': 4,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-08 00:00:00',
#    'unixtime': 1586293200,
#    'cum_confirmed': 189,
#    'cum_deaths': 7,
#    'cum_recovered': 44,
#    'active': 138,
#    'new_confirmed': 4,
#    'new_deaths': 1,
#    'new_recovered': 2,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-09 00:00:00',
#    'unixtime': 1586379600,
#    'cum_confirmed': 190,
#    'cum_deaths': 7,
#    'cum_recovered': 49,
#    'active': 134,
#    'new_confirmed': 1,
#    'new_deaths': 0,
#    'new_recovered': 5,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-10 00:00:00',
#    'unixtime': 1586466000,
#    'cum_confirmed': 190,
#    'cum_deaths': 7,
#    'cum_recovered': 54,
#    'active': 129,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 5,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-11 00:00:00',
#    'unixtime': 1586552400,
#    'cum_confirmed': 198,
#    'cum_deaths': 7,
#    'cum_recovered': 54,
#    'active': 137,
#    'new_confirmed': 8,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-12 00:00:00',
#    'unixtime': 1586638800,
#    'cum_confirmed': 210,
#    'cum_deaths': 7,
#    'cum_recovered': 56,
#    'active': 147,
#    'new_confirmed': 12,
#    'new_deaths': 0,
#    'new_recovered': 2,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-13 00:00:00',
#    'unixtime': 1586725200,
#    'cum_confirmed': 217,
#    'cum_deaths': 7,
#    'cum_recovered': 56,
#    'active': 154,
#    'new_confirmed': 7,
#    'new_deaths': 0,
#    'new_recovered': 0,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-14 00:00:00',
#    'unixtime': 1586811600,
#    'cum_confirmed': 233,
#    'cum_deaths': 7,
#    'cum_recovered': 61,
#    'active': 165,
#    'new_confirmed': 16,
#    'new_deaths': 0,
#    'new_recovered': 5,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-15 00:00:00',
#    'unixtime': 1586898000,
#    'cum_confirmed': 238,
#    'cum_deaths': 7,
#    'cum_recovered': 63,
#    'active': 168,
#    'new_confirmed': 5,
#    'new_deaths': 0,
#    'new_recovered': 2,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-16 00:00:00',
#    'unixtime': 1586984400,
#    'cum_confirmed': 238,
#    'cum_deaths': 7,
#    'cum_recovered': 68,
#    'active': 163,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 5,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-17 00:00:00',
#    'unixtime': 1587070800,
#    'cum_confirmed': 244,
#    'cum_deaths': 7,
#    'cum_recovered': 77,
#    'active': 160,
#    'new_confirmed': 6,
#    'new_deaths': 0,
#    'new_recovered': 9,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-18 00:00:00',
#    'unixtime': 1587157200,
#    'cum_confirmed': 254,
#    'cum_deaths': 7,
#    'cum_recovered': 86,
#    'active': 161,
#    'new_confirmed': 10,
#    'new_deaths': 0,
#    'new_recovered': 9,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-19 00:00:00',
#    'unixtime': 1587243600,
#    'cum_confirmed': 271,
#    'cum_deaths': 7,
#    'cum_recovered': 96,
#    'active': 168,
#    'new_confirmed': 17,
#    'new_deaths': 0,
#    'new_recovered': 10,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-20 00:00:00',
#    'unixtime': 1587330000,
#    'cum_confirmed': 304,
#    'cum_deaths': 7,
#    'cum_recovered': 98,
#    'active': 199,
#    'new_confirmed': 33,
#    'new_deaths': 0,
#    'new_recovered': 2,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-21 00:00:00',
#    'unixtime': 1587416400,
#    'cum_confirmed': 310,
#    'cum_deaths': 7,
#    'cum_recovered': 102,
#    'active': 201,
#    'new_confirmed': 6,
#    'new_deaths': 0,
#    'new_recovered': 4,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-22 00:00:00',
#    'unixtime': 1587502800,
#    'cum_confirmed': 330,
#    'cum_deaths': 7,
#    'cum_recovered': 105,
#    'active': 218,
#    'new_confirmed': 20,
#    'new_deaths': 0,
#    'new_recovered': 3,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-23 00:00:00',
#    'unixtime': 1587589200,
#    'cum_confirmed': 368,
#    'cum_deaths': 7,
#    'cum_recovered': 107,
#    'active': 254,
#    'new_confirmed': 38,
#    'new_deaths': 0,
#    'new_recovered': 2,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-24 00:00:00',
#    'unixtime': 1587675600,
#    'cum_confirmed': 420,
#    'cum_deaths': 7,
#    'cum_recovered': 109,
#    'active': 304,
#    'new_confirmed': 52,
#    'new_deaths': 0,
#    'new_recovered': 2,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-25 00:00:00',
#    'unixtime': 1587762000,
#    'cum_confirmed': 460,
#    'cum_deaths': 7,
#    'cum_recovered': 118,
#    'active': 335,
#    'new_confirmed': 40,
#    'new_deaths': 0,
#    'new_recovered': 9,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-26 00:00:00',
#    'unixtime': 1587848400,
#    'cum_confirmed': 523,
#    'cum_deaths': 7,
#    'cum_recovered': 120,
#    'active': 396,
#    'new_confirmed': 63,
#    'new_deaths': 0,
#    'new_recovered': 2,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-27 00:00:00',
#    'unixtime': 1587934800,
#    'cum_confirmed': 588,
#    'cum_deaths': 7,
#    'cum_recovered': 126,
#    'active': 455,
#    'new_confirmed': 65,
#    'new_deaths': 0,
#    'new_recovered': 6,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-28 00:00:00',
#    'unixtime': 1588021200,
#    'cum_confirmed': 619,
#    'cum_deaths': 7,
#    'cum_recovered': 134,
#    'active': 478,
#    'new_confirmed': 31,
#    'new_deaths': 0,
#    'new_recovered': 8,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-29 00:00:00',
#    'unixtime': 1588107600,
#    'cum_confirmed': 649,
#    'cum_deaths': 7,
#    'cum_recovered': 136,
#    'active': 506,
#    'new_confirmed': 30,
#    'new_deaths': 0,
#    'new_recovered': 2,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-04-30 00:00:00',
#    'unixtime': 1588194000,
#    'cum_confirmed': 663,
#    'cum_deaths': 7,
#    'cum_recovered': 154,
#    'active': 502,
#    'new_confirmed': 14,
#    'new_deaths': 0,
#    'new_recovered': 18,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-01 00:00:00',
#    'unixtime': 1588280400,
#    'cum_confirmed': 690,
#    'cum_deaths': 7,
#    'cum_recovered': 162,
#    'active': 521,
#    'new_confirmed': 27,
#    'new_deaths': 0,
#    'new_recovered': 8,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-02 00:00:00',
#    'unixtime': 1588366800,
#    'cum_confirmed': 705,
#    'cum_deaths': 7,
#    'cum_recovered': 172,
#    'active': 526,
#    'new_confirmed': 15,
#    'new_deaths': 0,
#    'new_recovered': 10,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-03 00:00:00',
#    'unixtime': 1588453200,
#    'cum_confirmed': 718,
#    'cum_deaths': 7,
#    'cum_recovered': 184,
#    'active': 527,
#    'new_confirmed': 13,
#    'new_deaths': 0,
#    'new_recovered': 12,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-04 00:00:00',
#    'unixtime': 1588539600,
#    'cum_confirmed': 751,
#    'cum_deaths': 8,
#    'cum_recovered': 194,
#    'active': 549,
#    'new_confirmed': 33,
#    'new_deaths': 1,
#    'new_recovered': 10,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-05 00:00:00',
#    'unixtime': 1588626000,
#    'cum_confirmed': 771,
#    'cum_deaths': 9,
#    'cum_recovered': 213,
#    'active': 549,
#    'new_confirmed': 20,
#    'new_deaths': 1,
#    'new_recovered': 19,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-06 00:00:00',
#    'unixtime': 1588712400,
#    'cum_confirmed': 797,
#    'cum_deaths': 9,
#    'cum_recovered': 215,
#    'active': 573,
#    'new_confirmed': 26,
#    'new_deaths': 0,
#    'new_recovered': 2,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-07 00:00:00',
#    'unixtime': 1588798800,
#    'cum_confirmed': 824,
#    'cum_deaths': 9,
#    'cum_recovered': 232,
#    'active': 583,
#    'new_confirmed': 27,
#    'new_deaths': 0,
#    'new_recovered': 17,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-08 00:00:00',
#    'unixtime': 1588885200,
#    'cum_confirmed': 835,
#    'cum_deaths': 9,
#    'cum_recovered': 240,
#    'active': 586,
#    'new_confirmed': 11,
#    'new_deaths': 0,
#    'new_recovered': 8,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-09 00:00:00',
#    'unixtime': 1588971600,
#    'cum_confirmed': 847,
#    'cum_deaths': 9,
#    'cum_recovered': 260,
#    'active': 578,
#    'new_confirmed': 12,
#    'new_deaths': 0,
#    'new_recovered': 20,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-10 00:00:00',
#    'unixtime': 1589058000,
#    'cum_confirmed': 863,
#    'cum_deaths': 9,
#    'cum_recovered': 321,
#    'active': 533,
#    'new_confirmed': 16,
#    'new_deaths': 0,
#    'new_recovered': 61,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-11 00:00:00',
#    'unixtime': 1589144400,
#    'cum_confirmed': 869,
#    'cum_deaths': 9,
#    'cum_recovered': 343,
#    'active': 517,
#    'new_confirmed': 6,
#    'new_deaths': 0,
#    'new_recovered': 22,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-12 00:00:00',
#    'unixtime': 1589230800,
#    'cum_confirmed': 889,
#    'cum_deaths': 9,
#    'cum_recovered': 366,
#    'active': 514,
#    'new_confirmed': 20,
#    'new_deaths': 0,
#    'new_recovered': 23,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-13 00:00:00',
#    'unixtime': 1589317200,
#    'cum_confirmed': 915,
#    'cum_deaths': 9,
#    'cum_recovered': 382,
#    'active': 524,
#    'new_confirmed': 26,
#    'new_deaths': 0,
#    'new_recovered': 16,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-14 00:00:00',
#    'unixtime': 1589403600,
#    'cum_confirmed': 925,
#    'cum_deaths': 9,
#    'cum_recovered': 445,
#    'active': 471,
#    'new_confirmed': 10,
#    'new_deaths': 0,
#    'new_recovered': 63,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-15 00:00:00',
#    'unixtime': 1589490000,
#    'cum_confirmed': 935,
#    'cum_deaths': 9,
#    'cum_recovered': 477,
#    'active': 449,
#    'new_confirmed': 10,
#    'new_deaths': 0,
#    'new_recovered': 32,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-16 00:00:00',
#    'unixtime': 1589576400,
#    'cum_confirmed': 960,
#    'cum_deaths': 9,
#    'cum_recovered': 520,
#    'active': 431,
#    'new_confirmed': 25,
#    'new_deaths': 0,
#    'new_recovered': 43,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-17 00:00:00',
#    'unixtime': 1589662800,
#    'cum_confirmed': 981,
#    'cum_deaths': 9,
#    'cum_recovered': 538,
#    'active': 434,
#    'new_confirmed': 21,
#    'new_deaths': 0,
#    'new_recovered': 18,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-18 00:00:00',
#    'unixtime': 1589749200,
#    'cum_confirmed': 992,
#    'cum_deaths': 9,
#    'cum_recovered': 559,
#    'active': 424,
#    'new_confirmed': 11,
#    'new_deaths': 0,
#    'new_recovered': 21,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-19 00:00:00',
#    'unixtime': 1589835600,
#    'cum_confirmed': 1027,
#    'cum_deaths': 9,
#    'cum_recovered': 569,
#    'active': 449,
#    'new_confirmed': 35,
#    'new_deaths': 0,
#    'new_recovered': 10,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-20 00:00:00',
#    'unixtime': 1589922000,
#    'cum_confirmed': 1028,
#    'cum_deaths': 9,
#    'cum_recovered': 584,
#    'active': 435,
#    'new_confirmed': 1,
#    'new_deaths': 0,
#    'new_recovered': 15,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-21 00:00:00',
#    'unixtime': 1590008400,
#    'cum_confirmed': 1055,
#    'cum_deaths': 9,
#    'cum_recovered': 604,
#    'active': 442,
#    'new_confirmed': 27,
#    'new_deaths': 0,
#    'new_recovered': 20,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-22 00:00:00',
#    'unixtime': 1590094800,
#    'cum_confirmed': 1068,
#    'cum_deaths': 9,
#    'cum_recovered': 620,
#    'active': 439,
#    'new_confirmed': 13,
#    'new_deaths': 0,
#    'new_recovered': 16,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-23 00:00:00',
#    'unixtime': 1590181200,
#    'cum_confirmed': 1089,
#    'cum_deaths': 9,
#    'cum_recovered': 660,
#    'active': 420,
#    'new_confirmed': 21,
#    'new_deaths': 0,
#    'new_recovered': 40,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-24 00:00:00',
#    'unixtime': 1590267600,
#    'cum_confirmed': 1141,
#    'cum_deaths': 9,
#    'cum_recovered': 674,
#    'active': 458,
#    'new_confirmed': 52,
#    'new_deaths': 0,
#    'new_recovered': 14,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-25 00:00:00',
#    'unixtime': 1590354000,
#    'cum_confirmed': 1182,
#    'cum_deaths': 10,
#    'cum_recovered': 695,
#    'active': 477,
#    'new_confirmed': 41,
#    'new_deaths': 1,
#    'new_recovered': 21,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-26 00:00:00',
#    'unixtime': 1590440400,
#    'cum_confirmed': 1319,
#    'cum_deaths': 10,
#    'cum_recovered': 712,
#    'active': 597,
#    'new_confirmed': 137,
#    'new_deaths': 0,
#    'new_recovered': 17,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-27 00:00:00',
#    'unixtime': 1590526800,
#    'cum_confirmed': 1469,
#    'cum_deaths': 10,
#    'cum_recovered': 732,
#    'active': 727,
#    'new_confirmed': 150,
#    'new_deaths': 0,
#    'new_recovered': 20,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-28 00:00:00',
#    'unixtime': 1590613200,
#    'cum_confirmed': 1530,
#    'cum_deaths': 10,
#    'cum_recovered': 745,
#    'active': 775,
#    'new_confirmed': 61,
#    'new_deaths': 0,
#    'new_recovered': 13,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-29 00:00:00',
#    'unixtime': 1590699600,
#    'cum_confirmed': 1558,
#    'cum_deaths': 10,
#    'cum_recovered': 754,
#    'active': 794,
#    'new_confirmed': 28,
#    'new_deaths': 0,
#    'new_recovered': 9,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-30 00:00:00',
#    'unixtime': 1590786000,
#    'cum_confirmed': 1620,
#    'cum_deaths': 10,
#    'cum_recovered': 781,
#    'active': 829,
#    'new_confirmed': 62,
#    'new_deaths': 0,
#    'new_recovered': 27,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-05-31 00:00:00',
#    'unixtime': 1590872400,
#    'cum_confirmed': 1633,
#    'cum_deaths': 10,
#    'cum_recovered': 801,
#    'active': 822,
#    'new_confirmed': 13,
#    'new_deaths': 0,
#    'new_recovered': 20,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-01 00:00:00',
#    'unixtime': 1590958800,
#    'cum_confirmed': 1643,
#    'cum_deaths': 11,
#    'cum_recovered': 811,
#    'active': 821,
#    'new_confirmed': 10,
#    'new_deaths': 1,
#    'new_recovered': 10,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-02 00:00:00',
#    'unixtime': 1591045200,
#    'cum_confirmed': 1683,
#    'cum_deaths': 11,
#    'cum_recovered': 823,
#    'active': 849,
#    'new_confirmed': 40,
#    'new_deaths': 0,
#    'new_recovered': 12,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-03 00:00:00',
#    'unixtime': 1591131600,
#    'cum_confirmed': 1749,
#    'cum_deaths': 11,
#    'cum_recovered': 836,
#    'active': 902,
#    'new_confirmed': 66,
#    'new_deaths': 0,
#    'new_recovered': 13,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-04 00:00:00',
#    'unixtime': 1591218000,
#    'cum_confirmed': 1797,
#    'cum_deaths': 11,
#    'cum_recovered': 839,
#    'active': 947,
#    'new_confirmed': 48,
#    'new_deaths': 0,
#    'new_recovered': 3,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-05 00:00:00',
#    'unixtime': 1591304400,
#    'cum_confirmed': 1801,
#    'cum_deaths': 11,
#    'cum_recovered': 858,
#    'active': 932,
#    'new_confirmed': 4,
#    'new_deaths': 0,
#    'new_recovered': 19,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-06 00:00:00',
#    'unixtime': 1591390800,
#    'cum_confirmed': 1814,
#    'cum_deaths': 11,
#    'cum_recovered': 891,
#    'active': 912,
#    'new_confirmed': 13,
#    'new_deaths': 0,
#    'new_recovered': 33,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-07 00:00:00',
#    'unixtime': 1591477200,
#    'cum_confirmed': 1835,
#    'cum_deaths': 11,
#    'cum_recovered': 941,
#    'active': 883,
#    'new_confirmed': 21,
#    'new_deaths': 0,
#    'new_recovered': 50,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-08 00:00:00',
#    'unixtime': 1591563600,
#    'cum_confirmed': 1857,
#    'cum_deaths': 11,
#    'cum_recovered': 990,
#    'active': 856,
#    'new_confirmed': 22,
#    'new_deaths': 0,
#    'new_recovered': 49,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-09 00:00:00',
#    'unixtime': 1591650000,
#    'cum_confirmed': 1859,
#    'cum_deaths': 11,
#    'cum_recovered': 1057,
#    'active': 791,
#    'new_confirmed': 2,
#    'new_deaths': 0,
#    'new_recovered': 67,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-10 00:00:00',
#    'unixtime': 1591736400,
#    'cum_confirmed': 1869,
#    'cum_deaths': 11,
#    'cum_recovered': 1122,
#    'active': 736,
#    'new_confirmed': 10,
#    'new_deaths': 0,
#    'new_recovered': 65,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-11 00:00:00',
#    'unixtime': 1591822800,
#    'cum_confirmed': 1877,
#    'cum_deaths': 11,
#    'cum_recovered': 1150,
#    'active': 716,
#    'new_confirmed': 8,
#    'new_deaths': 0,
#    'new_recovered': 28,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-12 00:00:00',
#    'unixtime': 1591909200,
#    'cum_confirmed': 1880,
#    'cum_deaths': 11,
#    'cum_recovered': 1196,
#    'active': 673,
#    'new_confirmed': 3,
#    'new_deaths': 0,
#    'new_recovered': 46,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-13 00:00:00',
#    'unixtime': 1591995600,
#    'cum_confirmed': 1884,
#    'cum_deaths': 11,
#    'cum_recovered': 1252,
#    'active': 621,
#    'new_confirmed': 4,
#    'new_deaths': 0,
#    'new_recovered': 56,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-14 00:00:00',
#    'unixtime': 1592082000,
#    'cum_confirmed': 1889,
#    'cum_deaths': 11,
#    'cum_recovered': 1287,
#    'active': 591,
#    'new_confirmed': 5,
#    'new_deaths': 0,
#    'new_recovered': 35,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-15 00:00:00',
#    'unixtime': 1592168400,
#    'cum_confirmed': 1905,
#    'cum_deaths': 11,
#    'cum_recovered': 1342,
#    'active': 552,
#    'new_confirmed': 16,
#    'new_deaths': 0,
#    'new_recovered': 55,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-16 00:00:00',
#    'unixtime': 1592254800,
#    'cum_confirmed': 1915,
#    'cum_deaths': 11,
#    'cum_recovered': 1371,
#    'active': 533,
#    'new_confirmed': 10,
#    'new_deaths': 0,
#    'new_recovered': 29,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-17 00:00:00',
#    'unixtime': 1592341200,
#    'cum_confirmed': 1924,
#    'cum_deaths': 11,
#    'cum_recovered': 1397,
#    'active': 516,
#    'new_confirmed': 9,
#    'new_deaths': 0,
#    'new_recovered': 26,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-18 00:00:00',
#    'unixtime': 1592427600,
#    'cum_confirmed': 1947,
#    'cum_deaths': 11,
#    'cum_recovered': 1421,
#    'active': 515,
#    'new_confirmed': 23,
#    'new_deaths': 0,
#    'new_recovered': 24,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-19 00:00:00',
#    'unixtime': 1592514000,
#    'cum_confirmed': 1950,
#    'cum_deaths': 11,
#    'cum_recovered': 1446,
#    'active': 493,
#    'new_confirmed': 3,
#    'new_deaths': 0,
#    'new_recovered': 25,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-20 00:00:00',
#    'unixtime': 1592600400,
#    'cum_confirmed': 1950,
#    'cum_deaths': 11,
#    'cum_recovered': 1472,
#    'active': 467,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 26,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-21 00:00:00',
#    'unixtime': 1592686800,
#    'cum_confirmed': 1950,
#    'cum_deaths': 11,
#    'cum_recovered': 1498,
#    'active': 441,
#    'new_confirmed': 0,
#    'new_deaths': 0,
#    'new_recovered': 26,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-22 00:00:00',
#    'unixtime': 1592773200,
#    'cum_confirmed': 1951,
#    'cum_deaths': 11,
#    'cum_recovered': 1526,
#    'active': 414,
#    'new_confirmed': 1,
#    'new_deaths': 0,
#    'new_recovered': 28,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-23 00:00:00',
#    'unixtime': 1592859600,
#    'cum_confirmed': 1991,
#    'cum_deaths': 11,
#    'cum_recovered': 1548,
#    'active': 432,
#    'new_confirmed': 40,
#    'new_deaths': 0,
#    'new_recovered': 22,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2020-06-24 00:00:00',
#    'unixtime': 1592946000,
#    'cum_confirmed': 2001,
#    'cum_deaths': 11,
#    'cum_recovered': 1562,
#    'active': 428,
#    'new_confirmed': 10,
#    'new_deaths': 0,
#    'new_recovered': 14,
#    'cum_vaccinations': 0,
#    'cum_people_vaccinated': 0,
#    'cum_people_fully_vaccinated': 0},
# ...
#    'cum_recovered': 94311,
#    'active': 6426,
#    'new_confirmed': 793,
#    'new_deaths': 4,
#    'new_recovered': 156,
#    'cum_vaccinations': 925242,
#    'cum_people_vaccinated': 925242,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2021-04-26 00:00:00',
#    'unixtime': 1619384400,
#    'cum_confirmed': 102376,
#    'cum_deaths': 647,
#    'cum_recovered': 94577,
#    'active': 7152,
#    'new_confirmed': 997,
#    'new_deaths': 5,
#    'new_recovered': 266,
#    'cum_vaccinations': 925242,
#    'cum_people_vaccinated': 925242,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2021-04-27 00:00:00',
#    'unixtime': 1619470800,
#    'cum_confirmed': 103487,
#    'cum_deaths': 647,
#    'cum_recovered': 94856,
#    'active': 7984,
#    'new_confirmed': 1111,
#    'new_deaths': 0,
#    'new_recovered': 279,
#    'cum_vaccinations': 925242,
#    'cum_people_vaccinated': 925242,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2021-04-28 00:00:00',
#    'unixtime': 1619557200,
#    'cum_confirmed': 104953,
#    'cum_deaths': 661,
#    'cum_recovered': 95083,
#    'active': 9209,
#    'new_confirmed': 1466,
#    'new_deaths': 14,
#    'new_recovered': 227,
#    'cum_vaccinations': 925242,
#    'cum_people_vaccinated': 925242,
#    'cum_people_fully_vaccinated': 0},
#   {'date': '2021-04-29 00:00:00',
#    'unixtime': 1619643600,
#    'cum_confirmed': 106484,
#    'cum_deaths': 661,
#    'cum_recovered': 95445,
#    'active': 10378,
#    'new_confirmed': 1531,
#    'new_deaths': 0,
#    'new_recovered': 362,
#    'cum_vaccinations': 933591,
#    'cum_people_vaccinated': 927711,
#    'cum_people_fully_vaccinated': 5880},
#   {'date': '2021-04-30 00:00:00',
#    'unixtime': 1619730000,
#    'cum_confirmed': 108146,
#    'cum_deaths': 678,
#    'cum_recovered': 95975,
#    'active': 11493,
#    'new_confirmed': 1662,
#    'new_deaths': 17,
#    'new_recovered': 530,
#    'cum_vaccinations': 953461,
#    'cum_people_vaccinated': 928107,
#    'cum_people_fully_vaccinated': 25354},
#   {'date': '2021-05-01 00:00:00',
#    'unixtime': 1619816400,
#    'cum_confirmed': 109862,
#    'cum_deaths': 687,
#    'cum_recovered': 96478,
#    'active': 12697,
#    'new_confirmed': 1716,
#    'new_deaths': 9,
#    'new_recovered': 503,
#    'cum_vaccinations': 991299,
#    'cum_people_vaccinated': 928107,
#    'cum_people_fully_vaccinated': 63192},
#   {'date': '2021-05-02 00:00:00',
#    'unixtime': 1619902800,
#    'cum_confirmed': 111753,
#    'cum_deaths': 696,
#    'cum_recovered': 97848,
#    'active': 13209,
#    'new_confirmed': 1891,
#    'new_deaths': 9,
#    'new_recovered': 1370,
#    'cum_vaccinations': 1016195,
#    'cum_people_vaccinated': 928107,
#    'cum_people_fully_vaccinated': 88088},
#   {'date': '2021-05-03 00:00:00',
#    'unixtime': 1619989200,
#    'cum_confirmed': 113676,
#    'cum_deaths': 709,
#    'cum_recovered': 98209,
#    'active': 14758,
#    'new_confirmed': 1923,
#    'new_deaths': 13,
#    'new_recovered': 361,
#    'cum_vaccinations': 1024978,
#    'cum_people_vaccinated': 928107,
#    'cum_people_fully_vaccinated': 96871},
#   {'date': '2021-05-04 00:00:00',
#    'unixtime': 1620075600,
#    'cum_confirmed': 115590,
#    'cum_deaths': 709,
#    'cum_recovered': 99153,
#    'active': 15728,
#    'new_confirmed': 1914,
#    'new_deaths': 0,
#    'new_recovered': 944,
#    'cum_vaccinations': 1048113,
#    'cum_people_vaccinated': 928107,
#    'cum_people_fully_vaccinated': 120006},
#   {'date': '2021-05-05 00:00:00',
#    'unixtime': 1620162000,
#    'cum_confirmed': 117529,
#    'cum_deaths': 734,
#    'cum_recovered': 100075,
#    'active': 16720,
#    'new_confirmed': 1939,
#    'new_deaths': 25,
#    'new_recovered': 922,
#    'cum_vaccinations': 1069828,
#    'cum_people_vaccinated': 928107,
#    'cum_people_fully_vaccinated': 141721},
#   {'date': '2021-05-06 00:00:00',
#    'unixtime': 1620248400,
#    'cum_confirmed': 119424,
#    'cum_deaths': 745,
#    'cum_recovered': 100885,
#    'active': 17794,
#    'new_confirmed': 1895,
#    'new_deaths': 11,
#    'new_recovered': 810,
#    'cum_vaccinations': 1088093,
#    'cum_people_vaccinated': 928107,
#    'cum_people_fully_vaccinated': 159986},
#   {'date': '2021-05-07 00:00:00',
#    'unixtime': 1620334800,
#    'cum_confirmed': 121338,
#    'cum_deaths': 764,
#    'cum_recovered': 101763,
#    'active': 18811,
#    'new_confirmed': 1914,
#    'new_deaths': 19,
#    'new_recovered': 878,
#    'cum_vaccinations': 1105342,
#    'cum_people_vaccinated': 928107,
#    'cum_people_fully_vaccinated': 177235},
#   {'date': '2021-05-08 00:00:00',
#    'unixtime': 1620421200,
#    'cum_confirmed': 123234,
#    'cum_deaths': 786,
#    'cum_recovered': 103098,
#    'active': 19350,
#    'new_confirmed': 1896,
#    'new_deaths': 22,
#    'new_recovered': 1335,
#    'cum_vaccinations': 1105342,
#    'cum_people_vaccinated': 928107,
#    'cum_people_fully_vaccinated': 177235},
#   {'date': '2021-05-09 00:00:00',
#    'unixtime': 1620507600,
#    'cum_confirmed': 125906,
#    'cum_deaths': 801,
#    'cum_recovered': 104463,
#    'active': 20642,
#    'new_confirmed': 2672,
#    'new_deaths': 15,
#    'new_recovered': 1365,
#    'cum_vaccinations': 1125740,
#    'cum_people_vaccinated': 928400,
#    'cum_people_fully_vaccinated': 197340},
#   {'date': '2021-05-10 00:00:00',
#    'unixtime': 1620594000,
#    'cum_confirmed': 128530,
#    'cum_deaths': 827,
#    'cum_recovered': 105611,
#    'active': 22092,
#    'new_confirmed': 2624,
#    'new_deaths': 26,
#    'new_recovered': 1148,
#    'cum_vaccinations': 1130257,
#    'cum_people_vaccinated': 931276,
#    'cum_people_fully_vaccinated': 198981},
#   {'date': '2021-05-11 00:00:00',
#    'unixtime': 1620680400,
#    'cum_confirmed': 131098,
#    'cum_deaths': 850,
#    'cum_recovered': 106641,
#    'active': 23607,
#    'new_confirmed': 2568,
#    'new_deaths': 23,
#    'new_recovered': 1030,
#    'cum_vaccinations': 1162770,
#    'cum_people_vaccinated': 948817,
#    'cum_people_fully_vaccinated': 213953},
#   {'date': '2021-05-12 00:00:00',
#    'unixtime': 1620766800,
#    'cum_confirmed': 133527,
#    'cum_deaths': 850,
#    'cum_recovered': 107657,
#    'active': 25020,
#    'new_confirmed': 2429,
#    'new_deaths': 0,
#    'new_recovered': 1016,
#    'cum_vaccinations': 1220248,
#    'cum_people_vaccinated': 996445,
#    'cum_people_fully_vaccinated': 223803},
#   {'date': '2021-05-13 00:00:00',
#    'unixtime': 1620853200,
#    'cum_confirmed': 135796,
#    'cum_deaths': 892,
#    'cum_recovered': 108802,
#    'active': 26102,
#    'new_confirmed': 2269,
#    'new_deaths': 42,
#    'new_recovered': 1145,
#    'cum_vaccinations': 1309840,
#    'cum_people_vaccinated': 1075848,
#    'cum_people_fully_vaccinated': 233992},
#   {'date': '2021-05-14 00:00:00',
#    'unixtime': 1620939600,
#    'cum_confirmed': 138085,
#    'cum_deaths': 923,
#    'cum_recovered': 110108,
#    'active': 27054,
#    'new_confirmed': 2289,
#    'new_deaths': 31,
#    'new_recovered': 1306,
#    'cum_vaccinations': 1384079,
#    'cum_people_vaccinated': 1140122,
#    'cum_people_fully_vaccinated': 243957},
#   {'date': '2021-05-15 00:00:00',
#    'unixtime': 1621026000,
#    'cum_confirmed': 140471,
#    'cum_deaths': 941,
#    'cum_recovered': 117220,
#    'active': 22310,
#    'new_confirmed': 2386,
#    'new_deaths': 18,
#    'new_recovered': 7112,
#    'cum_vaccinations': 1384079,
#    'cum_people_vaccinated': 1140122,
#    'cum_people_fully_vaccinated': 243957},
#   {'date': '2021-05-16 00:00:00',
#    'unixtime': 1621112400,
#    'cum_confirmed': 142746,
#    'cum_deaths': 962,
#    'cum_recovered': 118322,
#    'active': 23462,
#    'new_confirmed': 2275,
#    'new_deaths': 21,
#    'new_recovered': 1102,
#    'cum_vaccinations': 1541761,
#    'cum_people_vaccinated': 1273861,
#    'cum_people_fully_vaccinated': 267900},
#   {'date': '2021-05-17 00:00:00',
#    'unixtime': 1621198800,
#    'cum_confirmed': 145202,
#    'cum_deaths': 981,
#    'cum_recovered': 119629,
#    'active': 24592,
#    'new_confirmed': 2456,
#    'new_deaths': 19,
#    'new_recovered': 1307,
#    'cum_vaccinations': 1570070,
#    'cum_people_vaccinated': 1300558,
#    'cum_people_fully_vaccinated': 269512},
#   {'date': '2021-05-18 00:00:00',
#    'unixtime': 1621285200,
#    'cum_confirmed': 147720,
#    'cum_deaths': 1015,
#    'cum_recovered': 121145,
#    'active': 25560,
#    'new_confirmed': 2518,
#    'new_deaths': 34,
#    'new_recovered': 1516,
#    'cum_vaccinations': 1644957,
#    'cum_people_vaccinated': 1350065,
#    'cum_people_fully_vaccinated': 294892},
#   {'date': '2021-05-19 00:00:00',
#    'unixtime': 1621371600,
#    'cum_confirmed': 151343,
#    'cum_deaths': 1051,
#    'cum_recovered': 122367,
#    'active': 27925,
#    'new_confirmed': 3623,
#    'new_deaths': 36,
#    'new_recovered': 1222,
#    'cum_vaccinations': 1683203,
#    'cum_people_vaccinated': 1383082,
#    'cum_people_fully_vaccinated': 300121},
#   {'date': '2021-05-20 00:00:00',
#    'unixtime': 1621458000,
#    'cum_confirmed': 154786,
#    'cum_deaths': 1051,
#    'cum_recovered': 123532,
#    'active': 30203,
#    'new_confirmed': 3443,
#    'new_deaths': 0,
#    'new_recovered': 1165,
#    'cum_vaccinations': 1707323,
#    'cum_people_vaccinated': 1399927,
#    'cum_people_fully_vaccinated': 307396},
#   {'date': '2021-05-21 00:00:00',
#    'unixtime': 1621544400,
#    'cum_confirmed': 158333,
#    'cum_deaths': 1133,
#    'cum_recovered': 125360,
#    'active': 31840,
#    'new_confirmed': 3547,
#    'new_deaths': 82,
#    'new_recovered': 1828,
#    'cum_vaccinations': 1726749,
#    'cum_people_vaccinated': 1410615,
#    'cum_people_fully_vaccinated': 316134},
#   {'date': '2021-05-22 00:00:00',
#    'unixtime': 1621630800,
#    'cum_confirmed': 161242,
#    'cum_deaths': 1178,
#    'cum_recovered': 126995,
#    'active': 33069,
#    'new_confirmed': 2909,
#    'new_deaths': 45,
#    'new_recovered': 1635,
#    'cum_vaccinations': 1749366,
#    'cum_people_vaccinated': 1426735,
#    'cum_people_fully_vaccinated': 322631},
#   {'date': '2021-05-23 00:00:00',
#    'unixtime': 1621717200,
#    'cum_confirmed': 164201,
#    'cum_deaths': 1210,
#    'cum_recovered': 128607,
#    'active': 34384,
#    'new_confirmed': 2959,
#    'new_deaths': 32,
#    'new_recovered': 1612,
#    'cum_vaccinations': 1765378,
#    'cum_people_vaccinated': 1437147,
#    'cum_people_fully_vaccinated': 328231},
#   {'date': '2021-05-24 00:00:00',
#    'unixtime': 1621803600,
#    'cum_confirmed': 167172,
#    'cum_deaths': 1243,
#    'cum_recovered': 139947,
#    'active': 25982,
#    'new_confirmed': 2971,
#    'new_deaths': 33,
#    'new_recovered': 11340,
#    'cum_vaccinations': 1772924,
#    'cum_people_vaccinated': 1439501,
#    'cum_people_fully_vaccinated': 333423},
#   {'date': '2021-05-25 00:00:00',
#    'unixtime': 1621890000,
#    'cum_confirmed': 169900,
#    'cum_deaths': 1269,
#    'cum_recovered': 141175,
#    'active': 27456,
#    'new_confirmed': 2728,
#    'new_deaths': 26,
#    'new_recovered': 1228,
#    'cum_vaccinations': 1782429,
#    'cum_people_vaccinated': 1441501,
#    'cum_people_fully_vaccinated': 340928},
#   {'date': '2021-05-26 00:00:00',
#    'unixtime': 1621976400,
#    'cum_confirmed': 172277,
#    'cum_deaths': 1298,
#    'cum_recovered': 142378,
#    'active': 28601,
#    'new_confirmed': 2377,
#    'new_deaths': 29,
#    'new_recovered': 1203,
#    'cum_vaccinations': 1786343,
#    'cum_people_vaccinated': 1443066,
#    'cum_people_fully_vaccinated': 343277},
#   {'date': '2021-05-27 00:00:00',
#    'unixtime': 1622062800,
#    'cum_confirmed': 174861,
#    'cum_deaths': 1298,
#    'cum_recovered': 143789,
#    'active': 29774,
#    'new_confirmed': 2584,
#    'new_deaths': 0,
#    'new_recovered': 1411,
#    'cum_vaccinations': 1790688,
#    'cum_people_vaccinated': 1446712,
#    'cum_people_fully_vaccinated': 343976},
#   {'date': '2021-05-28 00:00:00',
#    'unixtime': 1622149200,
#    'cum_confirmed': 177711,
#    'cum_deaths': 1363,
#    'cum_recovered': 146362,
#    'active': 29986,
#    'new_confirmed': 2850,
#    'new_deaths': 65,
#    'new_recovered': 2573,
#    'cum_vaccinations': 1833048,
#    'cum_people_vaccinated': 1488651,
#    'cum_people_fully_vaccinated': 344397},
#   {'date': '2021-05-29 00:00:00',
#    'unixtime': 1622235600,
#    'cum_confirmed': 180593,
#    'cum_deaths': 1363,
#    'cum_recovered': 148391,
#    'active': 30839,
#    'new_confirmed': 2882,
#    'new_deaths': 0,
#    'new_recovered': 2029,
#    'cum_vaccinations': 1851001,
#    'cum_people_vaccinated': 1505273,
#    'cum_people_fully_vaccinated': 345728},
#   {'date': '2021-05-30 00:00:00',
#    'unixtime': 1622322000,
#    'cum_confirmed': 183452,
#    'cum_deaths': 1441,
#    'cum_recovered': 149825,
#    'active': 32186,
#    'new_confirmed': 2859,
#    'new_deaths': 78,
#    'new_recovered': 1434,
#    'cum_vaccinations': 1872990,
#    'cum_people_vaccinated': 1526750,
#    'cum_people_fully_vaccinated': 346240},
#   {'date': '2021-05-31 00:00:00',
#    'unixtime': 1622408400,
#    'cum_confirmed': 186364,
#    'cum_deaths': 1441,
#    'cum_recovered': 151740,
#    'active': 33183,
#    'new_confirmed': 2912,
#    'new_deaths': 0,
#    'new_recovered': 1915,
#    'cum_vaccinations': 1956742,
#    'cum_people_vaccinated': 1608518,
#    'cum_people_fully_vaccinated': 348224},
#   {'date': '2021-06-01 00:00:00',
#    'unixtime': 1622494800,
#    'cum_confirmed': 189241,
#    'cum_deaths': 1484,
#    'cum_recovered': 153371,
#    'active': 34386,
#    'new_confirmed': 2877,
#    'new_deaths': 43,
#    'new_recovered': 1631,
#    'cum_vaccinations': 2041307,
#    'cum_people_vaccinated': 1691562,
#    'cum_people_fully_vaccinated': 349745},
#   {'date': '2021-06-02 00:00:00',
#    'unixtime': 1622581200,
#    'cum_confirmed': 192547,
#    'cum_deaths': 1566,
#    'cum_recovered': 160714,
#    'active': 30267,
#    'new_confirmed': 3306,
#    'new_deaths': 82,
#    'new_recovered': 7343,
#    'cum_vaccinations': 2117653,
#    'cum_people_vaccinated': 1766636,
#    'cum_people_fully_vaccinated': 351017},
#   {'date': '2021-06-03 00:00:00',
#    'unixtime': 1622667600,
#    'cum_confirmed': 195844,
#    'cum_deaths': 1608,
#    'cum_recovered': 162397,
#    'active': 31839,
#    'new_confirmed': 3297,
#    'new_deaths': 42,
#    'new_recovered': 1683,
#    'cum_vaccinations': 2117653,
#    'cum_people_vaccinated': 1766636,
#    'cum_people_fully_vaccinated': 351017},
#   {'date': '2021-06-04 00:00:00',
#    'unixtime': 1622754000,
#    'cum_confirmed': 199254,
#    'cum_deaths': 1656,
#    'cum_recovered': 164281,
#    'active': 33317,
#    'new_confirmed': 3410,
#    'new_deaths': 48,
#    'new_recovered': 1884,
#    'cum_vaccinations': 2117653,
#    'cum_people_vaccinated': 1766636,
#    'cum_people_fully_vaccinated': 351017},
#   {'date': '2021-06-05 00:00:00',
#    'unixtime': 1622840400,
#    'cum_confirmed': 202357,
#    'cum_deaths': 1656,
#    'cum_recovered': 166132,
#    'active': 34569,
#    'new_confirmed': 3103,
#    'new_deaths': 0,
#    'new_recovered': 1851,
#    'cum_vaccinations': 2272260,
#    'cum_people_vaccinated': 1920801,
#    'cum_people_fully_vaccinated': 351459},
#   {'date': '2021-06-06 00:00:00',
#    'unixtime': 1622926800,
#    'cum_confirmed': 205333,
#    'cum_deaths': 1696,
#    'cum_recovered': 167304,
#    'active': 36333,
#    'new_confirmed': 2976,
#    'new_deaths': 40,
#    'new_recovered': 1172,
#    'cum_vaccinations': 2296864,
#    'cum_people_vaccinated': 1943708,
#    'cum_people_fully_vaccinated': 353156},
#   {'date': '2021-06-07 00:00:00',
#    'unixtime': 1623013200,
#    'cum_confirmed': 207979,
#    'cum_deaths': 1789,
#    'cum_recovered': 176045,
#    'active': 30145,
#    'new_confirmed': 2646,
#    'new_deaths': 93,
#    'new_recovered': 8741,
#    'cum_vaccinations': 2301489,
#    'cum_people_vaccinated': 1948187,
#    'cum_people_fully_vaccinated': 353302},
#   {'date': '2021-06-08 00:00:00',
#    'unixtime': 1623099600,
#    'cum_confirmed': 210661,
#    'cum_deaths': 1844,
#    'cum_recovered': 178259,
#    'active': 30558,
#    'new_confirmed': 2682,
#    'new_deaths': 55,
#    'new_recovered': 2214,
#    'cum_vaccinations': 2333591,
#    'cum_people_vaccinated': 1979802,
#    'cum_people_fully_vaccinated': 353789},
#   {'date': '2021-06-09 00:00:00',
#    'unixtime': 1623186000,
#    'cum_confirmed': 213396,
#    'cum_deaths': 1910,
#    'cum_recovered': 180427,
#    'active': 31059,
#    'new_confirmed': 2735,
#    'new_deaths': 66,
#    'new_recovered': 2168,
#    'cum_vaccinations': 2377211,
#    'cum_people_vaccinated': 2023256,
#    'cum_people_fully_vaccinated': 353955},
#   {'date': '2021-06-10 00:00:00',
#    'unixtime': 1623272400,
#    'cum_confirmed': 216134,
#    'cum_deaths': 1910,
#    'cum_recovered': 182238,
#    'active': 31986,
#    'new_confirmed': 2738,
#    'new_deaths': 0,
#    'new_recovered': 1811,
#    'cum_vaccinations': 2450965,
#    'cum_people_vaccinated': 2089320,
#    'cum_people_fully_vaccinated': 361645}]}

# %%
import datetime
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr

from covid19 import covid_data

#jhu_data = covid_data.load_jhu_data()
country_meta_datas = [
    {'alpha_2': 'IN', 'color': 'orange'},
    {'alpha_2': 'LK', 'color': 'maroon'},
    {'alpha_2': 'PK', 'color': 'lightgreen'},
    {'alpha_2': 'NP', 'color': 'blue'},
    {'alpha_2': 'BD', 'color': 'darkgreen'},
    {'alpha_2': 'AF', 'color': 'lightblue'},
    {'alpha_2': 'MV', 'color': 'red'},
    {'alpha_2': 'BT', 'color': 'purple'},
]

legend_labels = []
for country_meta_data in country_meta_datas:
    country_data = jhu_data[country_meta_data['alpha_2']]
    legend_labels.append(country_data['country_name'])
    timeseries = country_data['timeseries']
    population = country_data['population']

    x = list(map(
        lambda d: datetime.datetime.fromtimestamp(d['unixtime']),
        timeseries,
    ))
    y = list(map(
        lambda d: 100_000 * d['cum_deaths'] / population,
        timeseries,
    ))
    plt.plot(x, y, color=country_meta_data['color'])

plt.title('Total Deaths per 100,000 people in South Asia.')
plt.suptitle(
    'Data Source: https://github.com/CSSEGISandData/COVID-19',
    fontsize=6,
)
plt.legend(
    legend_labels,
    loc='upper left',
)

ax = plt.gca()
ax.get_yaxis().set_major_formatter(
    tkr.FuncFormatter(lambda x, p: format(int(x), ','))
)

fig = plt.gcf()
fig.autofmt_xdate()
fig.set_size_inches(8, 4.5)
fig.savefig('lk/img/death.png', dpi=600)

plt.show()

# %%
import datetime
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr

from covid19 import covid_data

#jhu_data = covid_data.load_jhu_data()
country_meta_datas = [
    {'alpha_2': 'IN', 'color': 'orange'},
    {'alpha_2': 'LK', 'color': 'maroon'},
    {'alpha_2': 'PK', 'color': 'lightgreen'},
    {'alpha_2': 'NP', 'color': 'blue'},
    {'alpha_2': 'BD', 'color': 'darkgreen'},
    {'alpha_2': 'AF', 'color': 'lightblue'},
    # {'alpha_2': 'MV', 'color': 'red'},
    {'alpha_2': 'BT', 'color': 'purple'},
]

legend_labels = []
for country_meta_data in country_meta_datas:
    country_data = jhu_data[country_meta_data['alpha_2']]
    legend_labels.append(country_data['country_name'])
    timeseries = country_data['timeseries']
    population = country_data['population']

    x = list(map(
        lambda d: datetime.datetime.fromtimestamp(d['unixtime']),
        timeseries,
    ))
    y = list(map(
        lambda d: 100_000 * d['active'] / population,
        timeseries,
    ))

    plt.plot(x, y, color=country_meta_data['color'])

plt.title(
    'Active COVID19Cases per 100,000 people in South Asia.',
)
plt.suptitle(
    'Data Source: https://github.com/CSSEGISandData/COVID-19',
    fontsize=6,
)
plt.legend(
    legend_labels,
    loc='upper left',
)

ax = plt.gca()
ax.get_yaxis().set_major_formatter(
    tkr.FuncFormatter(lambda x, p: format(int(x), ','))
)

fig = plt.gcf()
fig.autofmt_xdate()
fig.set_size_inches(8, 4.5)
fig.savefig('lk/img/active.png', dpi=600)

plt.show()

# %%
country_meta_datas = [
    #{'alpha_2': 'IN', 'color': 'orange'},
    {'alpha_2': 'LK', 'color': 'maroon'},
    #{'alpha_2': 'PK', 'color': 'lightgreen'},
    #{'alpha_2': 'NP', 'color': 'blue'},
    #{'alpha_2': 'BD', 'color': 'darkgreen'},
    #{'alpha_2': 'AF', 'color': 'lightblue'},
    # {'alpha_2': 'MV', 'color': 'red'},
    #{'alpha_2': 'BT', 'color': 'purple'},
]

legend_labels = []
for country_meta_data in country_meta_datas:
    country_data = jhu_data[country_meta_data['alpha_2']]
    legend_labels.append(country_data['country_name'])
    timeseries = country_data['timeseries']
    population = country_data['population']

    x = list(map(
        lambda d: datetime.datetime.fromtimestamp(d['unixtime']),
        timeseries,
    ))
    y = list(map(
        lambda d: 100_000 * d['active'] / population,
        timeseries,
    ))

    plt.plot(x, y, color=country_meta_data['color'])

plt.title(
    'Active COVID19Cases per 100,000 people in South Asia.',
)
plt.suptitle(
    'Data Source: https://github.com/CSSEGISandData/COVID-19',
    fontsize=6,
)
plt.legend(
    legend_labels,
    loc='upper left',
)

ax = plt.gca()
ax.get_yaxis().set_major_formatter(
    tkr.FuncFormatter(lambda x, p: format(int(x), ','))
)

fig = plt.gcf()
fig.autofmt_xdate()
fig.set_size_inches(8, 4.5)
fig.savefig('lk/img/active_SL.png', dpi=600)

plt.show()

# %%
import datetime
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr

from covid19 import covid_data

country_data = covid_data.load_jhu_data()['LK']
timeseries = country_data['timeseries']

x = list(map(
    lambda d: datetime.datetime.fromtimestamp(d['unixtime']),
    timeseries,
))
y1 = list(map(
    lambda d: d['active'],
    timeseries,
))
y2 = list(map(
    lambda d: d['cum_recovered'],
    timeseries,
))
y3 = list(map(
    lambda d: d['cum_deaths'],
    timeseries,
))

plt.stackplot(x, y1, y2, y3, colors=['blue', 'green', 'red'])

plt.title(
    'Daily COVID19 Active Cases, Total Recovered Cases, '
    + '& Total Deaths in %s.' % (country_data['country_name'])
)
plt.suptitle(
    'Data Source: https://github.com/CSSEGISandData/COVID-19 '
    + '& https://www.hpb.health.gov.lk/api/get-current-statistical',
    fontsize=6,
)
plt.legend(
    ['Active', 'Total Recovered', 'Total Deaths'],
    loc='upper left',
)

ax = plt.gca()
ax.get_yaxis().set_major_formatter(
    tkr.FuncFormatter(lambda x, p: format(int(x), ','))
)

fig = plt.gcf()
fig.autofmt_xdate()
fig.set_size_inches(12, 6.75)
fig.savefig('lk/img/recovered.png', dpi=600)

plt.show()

# %%
from covid19 import lk_data

timeseries = lk_data.get_timeseries()

x = list(map(
    lambda d: datetime.datetime.fromtimestamp(d['unixtime']),
    timeseries,
))
y = list(map(
    lambda d: d['new_confirmed'],
    timeseries,
))
plt.plot(x, y, color='red')

y2 = list(map(
    lambda d: d['new_pcr_tests'],
    timeseries,
))
plt.plot(x, y2, color='blue')

plt.title('Daily New COVID19 Cases and PCR Tests in Sri Lanka.')
plt.suptitle(
    'Data Source: https://github.com/CSSEGISandData/COVID-19',
    fontsize=6,
)
plt.legend(['Daily New Cases', 'Daily PCR Tests'])

ax = plt.gca()
ax.get_yaxis().set_major_formatter(
    tkr.FuncFormatter(lambda x, p: format(int(x), ','))
)

fig = plt.gcf()
fig.autofmt_xdate()
fig.set_size_inches(12, 6.75)
fig.savefig('lk/img/casesvstest.png', dpi=600)

plt.show()

# %%
import numpy as np

from covid19 import lk_data

timeseries = lk_data.get_timeseries()

x = list(map(
    lambda d: datetime.datetime.fromtimestamp(d['unixtime']),
    timeseries,
))

y = list(map(
    lambda d: d['new_confirmed'] / d['new_pcr_tests'] \
        if d['new_pcr_tests'] > 10 \
        else 0,
    timeseries,
))
plt.plot(x, y, color='pink')
N = 14
y = np.convolve(y, np.ones(N) / N, 'valid')
plt.plot(x[:-(N - 1)], y, color='red')

plt.title('Daily New COVID19 Cases per PCR Tests in Sri Lanka.')
plt.suptitle(
    'Data Source: https://github.com/CSSEGISandData/COVID-19 & https://www.hpb.health.gov.lk/api/get-current-statistical',
    fontsize=6,
)
plt.legend(['Cases per Test', '%d-Day Moving Window' % N])

ax = plt.gca()
ax.get_yaxis().set_major_formatter(
    tkr.FuncFormatter(lambda x, p: format(float(x), '.2%'))
)

fig = plt.gcf()
fig.autofmt_xdate()
fig.set_size_inches(12, 6.75)
fig.savefig('lk/img/pcrpercent.png', dpi=600)

plt.show()

# %%
legend_labels = []
country_meta_datas = [
    {'alpha_2': 'IN', 'color': 'orange'},
    {'alpha_2': 'LK', 'color': 'maroon'},
    {'alpha_2': 'PK', 'color': 'lightgreen'},
    {'alpha_2': 'NP', 'color': 'blue'},
    {'alpha_2': 'BD', 'color': 'darkgreen'},
    {'alpha_2': 'AF', 'color': 'lightblue'},
    # {'alpha_2': 'MV', 'color': 'red'},
    {'alpha_2': 'BT', 'color': 'purple'},
]
for country_meta_data in country_meta_datas:
    country_data = jhu_data[country_meta_data['alpha_2']]
    legend_labels.append(country_data['country_name'])
    timeseries = country_data['timeseries']
    population = country_data['population']

    x = list(map(
        lambda d: datetime.datetime.fromtimestamp(d['unixtime']),
        timeseries,
    ))
    y = list(map(
        lambda d: d['cum_people_vaccinated'] / population,
        timeseries,
    ))
    plt.plot(x, y, color=country_meta_data['color'])

plt.title('% People vaccinated in South Asia.')
plt.suptitle(
    'Data Source: https://github.com/CSSEGISandData/COVID-19 '
    + '& https://github.com/owid/covid-19-data',
    fontsize=6,
)
plt.legend(
    legend_labels,
    loc='upper left',
)

ax = plt.gca()
ax.get_yaxis().set_major_formatter(
    tkr.FuncFormatter(lambda x, p: format(float(x), '.2%'))
)

fig = plt.gcf()
fig.autofmt_xdate()
fig.set_size_inches(8, 4.5)
fig.savefig('lk/img/vaccinated.png', dpi=600)

plt.show()

# %%
country_alpha_2 = 'LK'
country_data = jhu_data[country_alpha_2]
country_name = country_data['country_name']
timeseries = country_data['timeseries'][-150:]
population = country_data['population']

x = list(map(
    lambda d: datetime.datetime.fromtimestamp(d['unixtime']),
    timeseries,
))
y1 = list(map(
    lambda d: d['cum_people_fully_vaccinated'] / population,
    timeseries,
))
y2 = list(map(
    lambda d:
        (d['cum_people_vaccinated'] - d['cum_people_fully_vaccinated'])
            / population,
    timeseries,
))

plt.stackplot(x, y1, y2, colors=['green', 'lightgreen'])

plt.title(
    '%% People Vaccinated in %s.' % (country_name)
)
plt.suptitle(
    'Data Source: https://github.com/CSSEGISandData/COVID-19'
    + '& https://www.hpb.health.gov.lk/api/get-current-statistical',
    fontsize=6,
)
plt.legend(
    ['Fully', 'Partially'],
    loc='upper left',
)

ax = plt.gca()
ax.get_yaxis().set_major_formatter(
    tkr.FuncFormatter(lambda x, p: format(float(x), '.2%'))
)

fig = plt.gcf()
fig.autofmt_xdate()
fig.set_size_inches(12, 6.75)
fig.savefig('lk/img/vaccinated_%s.png' % (country_alpha_2), dpi=600)

plt.show()

# %%
country_alpha_2 = 'LK'
country_data = jhu_data[country_alpha_2]
country_name = country_data['country_name']
timeseries = country_data['timeseries']

delay = 7
mortality_rate = timeseries[-1]['cum_deaths'] \
    / timeseries[-delay]['cum_confirmed']

x = list(map(
    lambda d: datetime.datetime.fromtimestamp(d['unixtime']),
    timeseries,
))
y1 = list(map(
    lambda d: d['new_deaths'],
    timeseries,
))
N = 7
y2 = np.convolve(y1, np.ones(N) / N, 'valid')
plt.plot(x[:-(N - 1)], y2, color='red')

y3 = list(map(
    lambda d: d['new_confirmed'] * mortality_rate,
    [{'new_confirmed': 0 } for _ in range(0, delay)] + timeseries[:-delay],
))
y4 = np.convolve(y3, np.ones(N) / N, 'valid')
plt.plot(x[:-(N - 1)], y4, color='blue')

plt.title(
    'New COVID19 Deaths in %s vs. "Predicted Deaths"' % (country_name)

)
plt.suptitle(
    'Data Source: https://github.com/CSSEGISandData/COVID-19 ',
    fontsize=6,
)
plt.legend([
    'New Deaths (%d Data Window)' % N,
    '"Predicted Deaths" = New Confirmed Cases %d days before *  %4.2f%%' % (delay, mortality_rate * 100.0),
])

ax = plt.gca()
ax.get_yaxis().set_major_formatter(
    tkr.FuncFormatter(lambda x, p: format(int(x), ','))
)

fig = plt.gcf()
fig.autofmt_xdate()
fig.set_size_inches(12, 6.75)
fig.savefig('lk/img/death_%s.png' % country_alpha_2, dpi=600)

plt.show()

# %%
country_alpha_2 = 'LK'
country_data = jhu_data[country_alpha_2]
country_name = country_data['country_name']
timeseries = country_data['timeseries'][-150:]
population = country_data['population']

x = list(map(
    lambda d: datetime.datetime.fromtimestamp(d['unixtime']),
    timeseries,
))
y1 = list(map(
    lambda d: d['cum_people_fully_vaccinated'] / population,
    timeseries,
))
y2 = list(map(
    lambda d: d['cum_people_vaccinated'] / population,
    timeseries,
))

legend = [
    'Fully Vaccinated',
    'At least 1st dose',
]
plt.plot(x, y1,  color="green")
plt.plot(x, y2,  color="lightgreen")

windows = [4, 6, 8, 10, 12, 14]
n_windows = len(windows)
for i, weeks in enumerate(windows):
    days_to_second_dose1 = 7 * weeks
    y = [0 for _ in range(0, days_to_second_dose1)] + list(map(
        lambda d: d['cum_people_vaccinated'] / population,
        timeseries[:-days_to_second_dose1],
    ))
    r = 1
    g = 0.8 - 0.8 * i / n_windows
    b = g
    plt.plot(x, y,  color=(r, g, b))
    legend.append('%d weeks since 1st dose' % weeks)

plt.title(
    '%% People Vaccinated in %s.' % (country_name)
)
plt.suptitle(
    'Data Source: https://github.com/CSSEGISandData/COVID-19'
    + '& https://www.hpb.health.gov.lk/api/get-current-statistical',
    fontsize=6,
)
plt.legend(
    legend,
    loc='upper left',
)

ax = plt.gca()
ax.get_yaxis().set_major_formatter(
    tkr.FuncFormatter(lambda x, p: format(float(x), '.2%'))
)

fig = plt.gcf()
fig.autofmt_xdate()
fig.set_size_inches(12, 6.75)
fig.savefig('lk/img/vaccinedelay_%s.png' % (country_alpha_2), dpi=300)

plt.show()

# %%
import os
field_key = 'new_deaths'
field_label = 'New Deaths per Day'
country_meta_datas = [
    {'alpha_2': 'IN', 'color': 'orange'},
    {'alpha_2': 'LK', 'color': 'maroon'},
    {'alpha_2': 'PK', 'color': 'lightgreen'},
    {'alpha_2': 'BD', 'color': 'darkgreen'},
    # {'alpha_2': 'NP', 'color': 'blue'},
    # {'alpha_2': 'AF', 'color': 'lightblue'},
    # {'alpha_2': 'MV', 'color': 'red'},
    # {'alpha_2': 'BT', 'color': 'purple'},
]

legend_labels = []
for country_meta_data in country_meta_datas:
    country_data = jhu_data[country_meta_data['alpha_2']]
    legend_labels.append(country_data['country_name'])
    timeseries = country_data['timeseries']
    population = country_data['population']

    x = list(map(
        lambda d: datetime.datetime.fromtimestamp(d['unixtime']),
        timeseries,
    ))
    y = list(map(
        lambda d: 100_000 * d[field_key] / population,
        timeseries,
    ))
    N = 14
    y = np.convolve(y, np.ones(N) / N, 'valid')
    plt.plot(x[:-(N - 1)], y, color=country_meta_data['color'])

plt.title(
    '%s per 100,000 people in South Asia (%d day average).' % (
        field_label,
        N,
    )
)
plt.suptitle(
    'Data Source: https://github.com/CSSEGISandData/COVID-19',
    fontsize=6,
)
plt.legend(
    legend_labels,
    loc='upper left',
)

ax = plt.gca()
ax.get_yaxis().set_major_formatter(
    tkr.FuncFormatter(lambda x, p: format(float(x), '.2'))
)

fig = plt.gcf()
fig.autofmt_xdate()
fig.set_size_inches(8, 4.5)
file_name = 'lk/img/newdeath.png'
fig.savefig(file_name, dpi=300)
os.system('open %s' % file_name)
# Out:
# 256

# %%
from gen import print_img

# %%
print_img("img/casesvstest.png", "Number of Active Cases vs. Tests", 1)
print_img("img/pcrpercent.png", "Number of Active Cases per PCR Test", 2)
print_img("img/active.png", "Active Covid Cases in Asia", 3)
print_img("img/active_SL.png", "Active Covid Cases in SL", 4)
print_img("img/recovered.png", "Total Recovered", 5)
print_img("img/vaccinated.png", "Percentage Vaccinated in Asia", 6)
print_img("img/vaccinated_LK.png", "Percentage Vaccinated in SL", 7)
print_img("img/vaccinedelay_LK.png", "Vaccination Delay", 8)
print_img("img/death.png", "Total Death in Asia", 9)
print_img("img/newdeath.png", "New Death in Asia", 10)
print_img("img/death_LK.png", "Total Death in SL and Predicted", 11)
# Out:
# <div class="gallery">
#   <img id="myImg1" src="img/casesvstest.png" alt="Number of Active Cases vs. Tests">
#   <div id="myModal1" class="modal">
#     <span class="close" id="close1">&times;</span>
#     <img class="modal-content" id="img01">
#     <div id="caption1"></div>
#   </div>
#   <div class="desc">Number of Active Cases vs. Tests</div>
# </div>
# <script>
# var modal1 = document.getElementById("myModal1");
# var img1 = document.getElementById("myImg1");
# var modalImg1 = document.getElementById("img01");
# var captionText1 = document.getElementById("caption1");
# img1.onclick = function(){
#   modal1.style.display = "block";
#   modalImg1.src = this.src;
#   captionText1.innerHTML = this.alt;
# }}
# var span1 = document.getElementById("close1");
# span1.onclick = function() {
#   modal1.style.display = "none";
# }}
# </script>
# <div class="gallery">
#   <img id="myImg2" src="img/pcrpercent.png" alt="Number of Active Cases per PCR Test">
#   <div id="myModal2" class="modal">
#     <span class="close" id="close2">&times;</span>
#     <img class="modal-content" id="img02">
#     <div id="caption2"></div>
#   </div>
#   <div class="desc">Number of Active Cases per PCR Test</div>
# </div>
# <script>
# var modal2 = document.getElementById("myModal2");
# var img2 = document.getElementById("myImg2");
# var modalImg2 = document.getElementById("img02");
# var captionText2 = document.getElementById("caption2");
# img2.onclick = function(){
#   modal2.style.display = "block";
#   modalImg2.src = this.src;
#   captionText2.innerHTML = this.alt;
# }}
# var span2 = document.getElementById("close2");
# span2.onclick = function() {
#   modal2.style.display = "none";
# }}
# </script>
# <div class="gallery">
#   <img id="myImg3" src="img/active.png" alt="Active Covid Cases in Asia">
#   <div id="myModal3" class="modal">
#     <span class="close" id="close3">&times;</span>
#     <img class="modal-content" id="img03">
#     <div id="caption3"></div>
#   </div>
#   <div class="desc">Active Covid Cases in Asia</div>
# </div>
# <script>
# var modal3 = document.getElementById("myModal3");
# var img3 = document.getElementById("myImg3");
# var modalImg3 = document.getElementById("img03");
# var captionText3 = document.getElementById("caption3");
# img3.onclick = function(){
#   modal3.style.display = "block";
#   modalImg3.src = this.src;
#   captionText3.innerHTML = this.alt;
# }}
# var span3 = document.getElementById("close3");
# span3.onclick = function() {
#   modal3.style.display = "none";
# }}
# </script>
# <div class="gallery">
#   <img id="myImg4" src="img/active_SL.png" alt="Active Covid Cases in SL">
#   <div id="myModal4" class="modal">
#     <span class="close" id="close4">&times;</span>
#     <img class="modal-content" id="img04">
#     <div id="caption4"></div>
#   </div>
#   <div class="desc">Active Covid Cases in SL</div>
# </div>
# <script>
# var modal4 = document.getElementById("myModal4");
# var img4 = document.getElementById("myImg4");
# var modalImg4 = document.getElementById("img04");
# var captionText4 = document.getElementById("caption4");
# img4.onclick = function(){
#   modal4.style.display = "block";
#   modalImg4.src = this.src;
#   captionText4.innerHTML = this.alt;
# }}
# var span4 = document.getElementById("close4");
# span4.onclick = function() {
#   modal4.style.display = "none";
# }}
# </script>
# <div class="gallery">
#   <img id="myImg5" src="img/recovered.png" alt="Total Recovered">
#   <div id="myModal5" class="modal">
#     <span class="close" id="close5">&times;</span>
#     <img class="modal-content" id="img05">
#     <div id="caption5"></div>
#   </div>
#   <div class="desc">Total Recovered</div>
# </div>
# <script>
# var modal5 = document.getElementById("myModal5");
# var img5 = document.getElementById("myImg5");
# var modalImg5 = document.getElementById("img05");
# var captionText5 = document.getElementById("caption5");
# img5.onclick = function(){
#   modal5.style.display = "block";
#   modalImg5.src = this.src;
#   captionText5.innerHTML = this.alt;
# }}
# var span5 = document.getElementById("close5");
# span5.onclick = function() {
#   modal5.style.display = "none";
# }}
# </script>
# <div class="gallery">
#   <img id="myImg6" src="img/vaccinated.png" alt="Percentage Vaccinated in Asia">
#   <div id="myModal6" class="modal">
#     <span class="close" id="close6">&times;</span>
#     <img class="modal-content" id="img06">
#     <div id="caption6"></div>
#   </div>
#   <div class="desc">Percentage Vaccinated in Asia</div>
# </div>
# <script>
# var modal6 = document.getElementById("myModal6");
# var img6 = document.getElementById("myImg6");
# var modalImg6 = document.getElementById("img06");
# var captionText6 = document.getElementById("caption6");
# img6.onclick = function(){
#   modal6.style.display = "block";
#   modalImg6.src = this.src;
#   captionText6.innerHTML = this.alt;
# }}
# var span6 = document.getElementById("close6");
# span6.onclick = function() {
#   modal6.style.display = "none";
# }}
# </script>
# <div class="gallery">
#   <img id="myImg7" src="img/vaccinated_LK.png" alt="Percentage Vaccinated in SL">
#   <div id="myModal7" class="modal">
#     <span class="close" id="close7">&times;</span>
#     <img class="modal-content" id="img07">
#     <div id="caption7"></div>
#   </div>
#   <div class="desc">Percentage Vaccinated in SL</div>
# </div>
# <script>
# var modal7 = document.getElementById("myModal7");
# var img7 = document.getElementById("myImg7");
# var modalImg7 = document.getElementById("img07");
# var captionText7 = document.getElementById("caption7");
# img7.onclick = function(){
#   modal7.style.display = "block";
#   modalImg7.src = this.src;
#   captionText7.innerHTML = this.alt;
# }}
# var span7 = document.getElementById("close7");
# span7.onclick = function() {
#   modal7.style.display = "none";
# }}
# </script>
# <div class="gallery">
#   <img id="myImg8" src="img/vaccinedelay_LK.png" alt="Vaccination Delay">
#   <div id="myModal8" class="modal">
#     <span class="close" id="close8">&times;</span>
#     <img class="modal-content" id="img08">
#     <div id="caption8"></div>
#   </div>
#   <div class="desc">Vaccination Delay</div>
# </div>
# <script>
# var modal8 = document.getElementById("myModal8");
# var img8 = document.getElementById("myImg8");
# var modalImg8 = document.getElementById("img08");
# var captionText8 = document.getElementById("caption8");
# img8.onclick = function(){
#   modal8.style.display = "block";
#   modalImg8.src = this.src;
#   captionText8.innerHTML = this.alt;
# }}
# var span8 = document.getElementById("close8");
# span8.onclick = function() {
#   modal8.style.display = "none";
# }}
# </script>
# <div class="gallery">
#   <img id="myImg9" src="img/death.png" alt="Total Death in Asia">
#   <div id="myModal9" class="modal">
#     <span class="close" id="close9">&times;</span>
#     <img class="modal-content" id="img09">
#     <div id="caption9"></div>
#   </div>
#   <div class="desc">Total Death in Asia</div>
# </div>
# <script>
# var modal9 = document.getElementById("myModal9");
# var img9 = document.getElementById("myImg9");
# var modalImg9 = document.getElementById("img09");
# var captionText9 = document.getElementById("caption9");
# img9.onclick = function(){
#   modal9.style.display = "block";
#   modalImg9.src = this.src;
#   captionText9.innerHTML = this.alt;
# }}
# var span9 = document.getElementById("close9");
# span9.onclick = function() {
#   modal9.style.display = "none";
# }}
# </script>
# <div class="gallery">
#   <img id="myImg10" src="img/newdeath.png" alt="New Death in Asia">
#   <div id="myModal10" class="modal">
#     <span class="close" id="close10">&times;</span>
#     <img class="modal-content" id="img010">
#     <div id="caption10"></div>
#   </div>
#   <div class="desc">New Death in Asia</div>
# </div>
# <script>
# var modal10 = document.getElementById("myModal10");
# var img10 = document.getElementById("myImg10");
# var modalImg10 = document.getElementById("img010");
# var captionText10 = document.getElementById("caption10");
# img10.onclick = function(){
#   modal10.style.display = "block";
#   modalImg10.src = this.src;
#   captionText10.innerHTML = this.alt;
# }}
# var span10 = document.getElementById("close10");
# span10.onclick = function() {
#   modal10.style.display = "none";
# }}
# </script>
# <div class="gallery">
#   <img id="myImg11" src="img/death_LK.png" alt="Total Death in SL and Predicted">
#   <div id="myModal11" class="modal">
#     <span class="close" id="close11">&times;</span>
#     <img class="modal-content" id="img011">
#     <div id="caption11"></div>
#   </div>
#   <div class="desc">Total Death in SL and Predicted</div>
# </div>
# <script>
# var modal11 = document.getElementById("myModal11");
# var img11 = document.getElementById("myImg11");
# var modalImg11 = document.getElementById("img011");
# var captionText11 = document.getElementById("caption11");
# img11.onclick = function(){
#   modal11.style.display = "block";
#   modalImg11.src = this.src;
#   captionText11.innerHTML = this.alt;
# }}
# var span11 = document.getElementById("close11");
# span11.onclick = function() {
#   modal11.style.display = "none";
# }}
# </script>
